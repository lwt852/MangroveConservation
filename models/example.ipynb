# %%
search term = (mangrove ecosystems)OR(mangrove forests)OR(Mangrove Ecosystems)OR(Mangrove Forests)OR(Mangrove Ecosystems)OR(Mangrove Forests)
search_location = CH
start_time =20150101
end_time=20191231
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-b43ddab5785e> in <module>
#       3 # Reference: https://developer.twitter.com/en/docs/tweets/search/overview
#       4
# ----> 5 from TwitterAPI import TwitterAPI, TwitterPager
#       6 import csv
#       7
#
# ModuleNotFoundError: No module named 'TwitterAPI'

# %%
import TwitterAPI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-534fa92c925d> in <module>
# ----> 1 impor
#
# NameError: name 'impor' is not defined
